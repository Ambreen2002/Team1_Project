# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
csv = pd.read_csv("final_clean_df.csv", index_col="Date", parse_dates=True, infer_datetime_format=True)
csv.head()
# Out:
#               SP500      A    AAP   AAPL    ABC     ABT    ACN   ADBE    ADI  \
# Date
# 2012-01-03  1277.06  36.48  69.11  8.391  38.08  27.209  52.96  28.61  36.07
# 2012-01-04  1277.30  36.18  70.69  8.437  38.20  27.099  52.93  28.28  35.97
# 2012-01-05  1281.06  37.01  71.20  8.530  38.48  27.042  51.94  28.48  36.15
# 2012-01-06  1277.81  37.43  71.52  8.621  38.59  26.802  51.82  28.75  35.85
# 2012-01-09  1280.70  38.37  71.46  8.606  38.58  26.792  51.72  28.51  36.59
#
#               ADM  ...     WY    WYNN    XEL    XLNX    XRX    XYL    YUM  \
# Date               ...
# 2012-01-03  24.41  ...  19.11  113.97  27.33  32.440  32.76  25.10  58.55
# 2012-01-04  24.81  ...  18.89  112.01  27.17  32.095  32.60  25.93  58.99
# 2012-01-05  29.25  ...  18.80  110.85  27.26  32.370  32.40  25.60  59.41
# 2012-01-06  24.56  ...  19.01  106.94  27.19  32.160  32.36  25.17  59.88
# 2012-01-09  24.42  ...  18.80  106.64  27.21  32.870  32.32  25.25  59.60
#
# ...

# %%
returns_df = csv.pct_change()
returns_df.head()
# Out:
#                SP500         A       AAP      AAPL       ABC       ABT  \
# Date
# 2012-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-01-04  0.000188 -0.008224  0.022862  0.005482  0.003151 -0.004043
# 2012-01-05  0.002944  0.022941  0.007215  0.011023  0.007330 -0.002103
# 2012-01-06 -0.002537  0.011348  0.004494  0.010668  0.002859 -0.008875
# 2012-01-09  0.002262  0.025114 -0.000839 -0.001740 -0.000259 -0.000373
#
#                  ACN      ADBE       ADI       ADM  ...        WY      WYNN  \
# Date                                                ...
# 2012-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2012-01-04 -0.000566 -0.011534 -0.002772  0.016387  ... -0.011512 -0.017198
# 2012-01-05 -0.018704  0.007072  0.005004  0.178960  ... -0.004764 -0.010356
# 2012-01-06 -0.002310  0.009480 -0.008299 -0.160342  ...  0.011170 -0.035273
# 2012-01-09 -0.001930 -0.008348  0.020642 -0.005700  ... -0.011047 -0.002805
#
# ...

# %%
returns_df = returns_df.dropna()
returns_df.head()
# Out:
#                SP500         A       AAP      AAPL       ABC       ABT  \
# Date
# 2012-01-04  0.000188 -0.008224  0.022862  0.005482  0.003151 -0.004043
# 2012-01-05  0.002944  0.022941  0.007215  0.011023  0.007330 -0.002103
# 2012-01-06 -0.002537  0.011348  0.004494  0.010668  0.002859 -0.008875
# 2012-01-09  0.002262  0.025114 -0.000839 -0.001740 -0.000259 -0.000373
# 2012-01-10  0.008886  0.018765  0.001120  0.003602  0.011146 -0.582002
#
#                  ACN      ADBE       ADI       ADM  ...        WY      WYNN  \
# Date                                                ...
# 2012-01-04 -0.000566 -0.011534 -0.002772  0.016387  ... -0.011512 -0.017198
# 2012-01-05 -0.018704  0.007072  0.005004  0.178960  ... -0.004764 -0.010356
# 2012-01-06 -0.002310  0.009480 -0.008299 -0.160342  ...  0.011170 -0.035273
# 2012-01-09 -0.001930 -0.008348  0.020642 -0.005700  ... -0.011047 -0.002805
# 2012-01-10  0.018175  0.023851  0.004373 -0.004505  ...  0.020745  0.008346
#
# ...

# %%
volatility = returns_df.std().sort_values(ascending=False)
volatility.head()
# Out:
# AAPL     1.911529
# CF       1.821474
# CME.1    0.932614
# CME      0.932614
# CRM      0.858756
# dtype: float64

# %%
covariance = returns_df['A'].cov(returns_df['SP500'])
variance = returns_df['A'].var()
beta = covariance/variance
beta
# Out:
# 0.3035871966032029

# %%
index_returns = returns_df.iloc[:,0]
index_returns
# Out:
# Date
# 2012-01-04    0.000188
# 2012-01-05    0.002944
# 2012-01-06   -0.002537
# 2012-01-09    0.002262
# 2012-01-10    0.008886
#                 ...
# 2016-12-23    0.001252
# 2016-12-27    0.002248
# 2016-12-28   -0.008357
# 2016-12-29   -0.000293
# 2016-12-30   -0.004637
# Name: SP500, Length: 1257, dtype: float64

# %%
def find_beta(df):

    index_returns = df.iloc[:,0]
    df_beta = {}
    
    for ticker in df:
        covariance = df[ticker].cov(index_returns)
        variance = df[ticker].var()
        beta = covariance/variance
        df_beta[ticker] = beta
    
    return df_beta

# %%
find_beta(returns_df)
# Out:
# {'SP500': 0.9999999999999998,
#  'A': 0.3035871966032029,
#  'AAP': 0.19161540612082822,
#  'AAPL': -3.652744988031694e-05,
#  'ABC': 0.12937119443202713,
#  'ABT': 0.000914220950139758,
#  'ACN': 0.4345017007872213,
#  'ADBE': 0.32384945805408,
#  'ADI': 0.36573939042957954,
#  'ADM': 0.013374914296472609,
#  'ADP': 0.01612776438192279,
#  'ADSK': 0.24126197163268895,
#  'AEE': 0.3095123955823458,
#  'AEP': 0.004542393211999587,
#  'AES': 0.28181532115828434,
#  'AFL': 0.00017620357400973256,
#  'AIG': 0.3871398415730596,
#  'AIV': 0.010313495247687945,
#  'AIZ': 0.01345894057450224,
#  'AJG': 0.5845924606158792,
#  'AKAM': 0.1698639624516332,
#  'ALB': 0.26978319171123344,
#  'ALGN': 0.17331650745331859,
#  'ALK': 0.034845202599059745,
#  'ALL': 0.018325588025667954,
#  'ALXN': 0.16858247606065366,
#  'AMAT': 0.29781363074964146,
#  'AMD': 0.07563950936454587,
#  'AME': 0.006982451658187825,
#  'AMGN': 0.013307925202537431,
#  'AMP': 0.4005707828974014,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-2610c0b8f95c> in <module>
# ----> 1 findbeta(returns_df)
#
# <ipython-input-41-e4948c818a42> in findbeta(df)
#       9         beta = (covariance/variance)
#      10
# ---> 11         df_beta[ticker].append(beta)
#      12
#      13     return df_beta
#
# KeyError: 'SP500'

# %%
covariance = daily_returns['MSFT'].cov(daily_returns['SP500'])
covariance

# %%
returns_df.loc[:,"SP500"]
# Out:
# Date
# 2012-01-04    0.000188
# 2012-01-05    0.002944
# 2012-01-06   -0.002537
# 2012-01-09    0.002262
# 2012-01-10    0.008886
#                 ...
# 2016-12-23    0.001252
# 2016-12-27    0.002248
# 2016-12-28   -0.008357
# 2016-12-29   -0.000293
# 2016-12-30   -0.004637
# Name: SP500, Length: 1257, dtype: float64
